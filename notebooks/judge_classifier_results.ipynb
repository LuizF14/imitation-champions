# %% [markdown]
# # Resultados do Qwen 2.5 com fine tuning

# %%
import pandas as pd

qwen2_5_results = pd.read_csv("results/judge_evaluation_qwen2_5_classifier.csv")

qwen2_5_accuracy = qwen2_5_results["is_correct"].mean()
print(f"Acurácia do Qwen 2.5 com fine tuning: {(qwen2_5_accuracy)*100:.2f}%")
# Out:
# Acurácia do Qwen 2.5 com fine tuning: 80.06%
